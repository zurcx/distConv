# %%
# contar numeros de linhas do arquivo
# Opening a file
file = open("original.txt","r")
Counter = 0
  
# Reading from file
Content = file.read()
CoList = Content.split("\n")
  
for i in CoList:
    if i:
        Counter += 1
          
print("This is the number of lines in the file")
print(Counter)
# Out:
# This is the number of lines in the file
# 10

# %%
num_lines = Counter
print(num_lines)
# Out:
# 10

# %%
with open("original0002.txt") as f:
    arq_conv = open("00004002510000559conv.txt", "w")
    arq_conv.close()
    for line in f:
        #do something with data
        o_size = (len(line.strip()))
        n_size = 38
        #print(o_size)
        #print(line)
        after_sx = line[:]
        after_s = line[:]
        befo_s = line[:34]+"\n"
        

        
        if o_size < n_size:
            print(after_s)
            arq_fill = open("00004002510000559conv.txt", "r")
            conteudo = arq_fill.readlines()
            conteudo.append(after_s)
            arq_fill = open("00004002510000559conv.txt", "w")
            arq_fill.writelines(conteudo)
            arq_fill.close()
            
        elif o_size > n_size:
            print(after_sx)
            arq_fill = open("00004002510000559conv.txt", "r")
            conteudo = arq_fill.readlines()
            conteudo.append(after_sx)
            arq_fill = open("00004002510000559conv.txt", "w")
            arq_fill.writelines(conteudo)
            arq_fill.close()
            arquivo = open("00004002510000559conv.txt", "r")
            
            
        else:
            print(befo_s)
            arq_fill = open("00004002510000559conv.txt", "r")
            conteudo = arq_fill.readlines()
            conteudo.append(befo_s)
            arq_fill = open("00004002510000559conv.txt", "w")
            arq_fill.writelines(conteudo)
            arq_fill.close()
            
       
arquivo = open("00004002510000559conv.txt", "r")
for linhas in arquivo:
    linhas = arquivo.read().splitlines()

    
'''
 
lista_stopwords = [line.strip() for line in file_stopwords if line.strip() != ""]
Perceba a adição da condição if line.strip() != "" ao final da linha. Com isso você já garantirá que apenas as linhas com algum conteúdo diferente de da quebra de linha não sejam incluídas na lista.

Veja um exemplo:

words = ["a\n", "\n", "ok\n", "\n", ""]

print([word.strip() for word in words if word.strip() != ""])

# ['a', 'ok']

 
'''
# Out:
# 0000000001186897113000157            FUNDACAO DE APOIO AO HEMOSC/CEPON                                                                                                                     000040025100005590204202120042021200420211559278D
#
# 000167768602042021000202
#
# 000167769602042021004602
#
# 0001677703050420210557019032558199
#
# 0001677713050420210629012702247727
#
# 0001677723050420210636017061320549
#
# 0001677733050420210636012347782764
#
# 0001677743050420210654012336647674
#
# 0001677753050420210700012543470915
#
# 0001677763050420210700012537529318
#
# 0001677773050420210700010877632275
#
# 0001677783050420210700012220717277
#
# 0001677793050420210700013823193723
#
# 0001677803050420210700012403496393
#
# 0001677813050420210703012951241676
#
# 0001677823050420210704013564548725
#
# 0001677833050420210704012341910124
#
# 0001677843050420210705013710396726
#
# 0001677853050420210705012320576268
#
# 0001677863050420210711010865025883
#
# 0001677873050420210712011378405050
# ...
